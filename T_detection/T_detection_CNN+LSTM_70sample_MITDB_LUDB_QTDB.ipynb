# %% [markdown]
# <a href="https://colab.research.google.com/github/ab2gbl/ECG-detection/blob/main/T_detection/T_detection_CNN%2BLSTM_70sample_MITDB_LUDB_QTDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir /content/physionet.org/
# !mkdir /content/physionet.org/files/
# !cp -r '/content/drive/MyDrive/Final project/dataset/physionet.org/files/ludb' '/content/physionet.org/files/'
# !cp -r '/content/drive/MyDrive/Final project/dataset/physionet.org/files/qtdb' '/content/physionet.org/files/'
# Out:
# mkdir: cannot create directory ‘/content/physionet.org/’: File exists
# mkdir: cannot create directory ‘/content/physionet.org/files/’: File exists

# %%
# !cp -r '/content/physionet.org/files/edb' '/content/drive/MyDrive/Final project/dataset/physionet.org/files/edb'

# %%
# !pip install wfdb numpy scipy matplotlib scikit-learn tensorflow
# Out:
# Collecting wfdb
#   Downloading wfdb-4.2.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.14.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Collecting pandas>=2.2.3 (from wfdb)
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.32.3)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2025.1.31)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.10.0->wfdb) (1.17.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading wfdb-4.2.0-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.3/162.3 kB 7.2 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 92.1 MB/s eta 0:00:00
# Installing collected packages: pandas, wfdb
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# Successfully installed pandas-2.2.3 wfdb-4.2.0

# %% [markdown]
# # Gloabal variables

# %%
G_window_size = 65
G_overlap = 60
G_fs = 360
G_q_offset = 30

# %% [markdown]
# # 1- Signal traitement functions

# %% [markdown]
# ## 1-1- Preprocess the Signal

# %% [markdown]
# ### A. Filtering

# %%
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt

def bandpass_filter(data, fs, lowcut=0.5, highcut=40.0, order=4):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = signal.butter(order, [low, high], btype='band')
    filtered = signal.filtfilt(b, a, data)
    return filtered

def differentiate_signal(data, fs):
    # Differentiate the signal using a first-order difference
    differentiated = np.diff(data, prepend=data[0])
    return differentiated

def smooth_signal(data, window_size=5):
    # Smooth the signal using a moving average filter
    window = np.ones(window_size) / window_size
    smoothed = np.convolve(data, window, mode='same')
    return smoothed

from scipy.signal import resample
def resample_signal(signal, original_fs, target_fs=360):
    num_samples = int(len(signal) * target_fs / original_fs)
    resampled_signal = resample(signal, num_samples)
    return resampled_signal

def adjust_annotation(point, original_fs, target_fs):
    point = np.array(point)  # 🔥 Make sure it's a NumPy array
    return int((point * target_fs / original_fs).astype(int))

# %% [markdown]
# ### B. Normalization

# %%
def normalize_signal(data):
    """
    Normalize the signal using z-score normalization.
    """
    return (data - np.mean(data)) / np.std(data)

# %% [markdown]
# ## 1-2- Segment the Signal for QRS Detection

# %%
import numpy as np

def segment_signal(signal, window_size=G_window_size, overlap=G_overlap ):
    """
    Segment the signal into fixed-length windows with a specified overlap.

    Args:
        signal (np.array): The input signal.
        window_size (int): Length of each segment (in samples).
        overlap (int): Number of overlapping samples between consecutive segments.

    Returns:
        tuple: (Array of segmented windows, Array of segment start indices)
    """
    segments = []
    segment_indices = []

    step = window_size - overlap  # Step size for sliding window
    for start in range(0, len(signal) - window_size + 1, step):
        end = start + window_size
        segments.append(signal[start:end])
        segment_indices.append(start)  # Store segment start position

    return np.array(segments), np.array(segment_indices)

# %% [markdown]
# ## 1-3- Labeling and Combining the Data

# %%
import numpy as np

def label_segments(normalized_signal,segments, segment_starts, qrs_indices, q_offset=G_q_offset, window_size=G_window_size, overlap=G_overlap):
    """
    Label each segment as QRS (1) or non-QRS (0), ensuring an equal number of 0 and 1 labels.

    Args:
        segments (np.array): Array of segmented windows.
        segment_starts (np.array): Start indices of segments.
        qrs_indices (list): List of QRS indices (in samples).
        window_size (int): Length of each segment (in samples).
        overlap (int): Number of overlapping samples between consecutive segments.

    Returns:
        np.array: Array of labels (1 for QRS, 0 for non-QRS).
    """
    labels = np.zeros(len(segments), dtype=int)

    # Label QRS segments
    for i, segment_start in enumerate(segment_starts):
        segment_end = segment_start + window_size

        # Check if any QRS index falls within this segment
        for r_peak in qrs_indices:
            q_start = r_peak - q_offset  # Approximate Q start
            s_end = r_peak + q_offset    # Approximate S end

            # Ensure q_start and s_end are within bounds
            q_start = max(0, q_start)
            s_end = min(len(normalized_signal) - 1, s_end)

            if segment_start <= q_start and segment_end >= s_end:
                labels[i] = 1
                break

    # Balance the dataset by randomly sampling non-QRS segments
    qrs_count = np.sum(labels == 1)  # Number of QRS segments
    non_qrs_indices = np.where(labels == 0)[0]  # Indices of non-QRS segments

    # Randomly sample non-QRS segments to match the number of QRS segments
    if len(non_qrs_indices) > qrs_count:
        sampled_non_qrs_indices = np.random.choice(non_qrs_indices, size=qrs_count, replace=False)
        labels[sampled_non_qrs_indices] = 0  # Ensure sampled non-QRS segments are labeled as 0
    else:
        print("Warning: Not enough non-QRS segments to balance the dataset.")

    return labels

# %%
import numpy as np
import matplotlib.pyplot as plt
def display_segment(normalized_signal,segment_labels,segment_starts,z_start,z_end):
  # Define sampling rate

  # Define zoom window in **seconds**
  zoom_start_sec = z_start   # Start time in seconds
  zoom_end_sec = z_end     # End time in seconds

  # Convert zoom window from seconds to samples
  zoom_start = zoom_start_sec * G_fs  # Convert to sample index
  zoom_end = zoom_end_sec * G_fs      # Convert to sample index

  # Function to filter windows within the zoom range (in sample indices)
  def filter_windows_in_zoom(windows, zoom_start, zoom_end):
      """Filter windows that fall within the zoom range in samples."""
      return [(start, end) for start, end in windows if start < zoom_end and end > zoom_start]

  # Identify segment start and end in samples
  positive_windows = [(segment_starts[i], segment_starts[i] + G_window_size) for i in range(len(segment_labels)) if segment_labels[i] == 1]
  negative_windows = [(segment_starts[i], segment_starts[i] + G_window_size) for i in range(len(segment_labels)) if segment_labels[i] == 0]
  print("Number of positive (QRS) segments:", len(positive_windows))
  print("Number of negative (non-QRS) segments:", len(negative_windows))
  # Filter positive and negative windows within the zoom range
  positive_windows_zoom = filter_windows_in_zoom(positive_windows, zoom_start, zoom_end)
  negative_windows_zoom = filter_windows_in_zoom(negative_windows, zoom_start, zoom_end)

  # Create time axis in **seconds**
  time_axis = np.arange(len(normalized_signal)) / G_fs  # Convert samples to seconds

  # Plot 1: Positive (QRS) Segments
  plt.figure(figsize=(12, 4))
  plt.plot(time_axis, normalized_signal, label="ECG Signal", color="blue")

  # Highlight positive (QRS) windows in red (only within the zoom range)
  for start, end in positive_windows_zoom:
      plt.axvspan(start / G_fs, end / G_fs, color="red", alpha=0.3, label="QRS Segment" if start == positive_windows_zoom[0][0] else "")

  plt.title(f"Positive (QRS) Segments (Window Size: {G_window_size} samples, Overlap: {G_overlap} samples)")
  plt.xlabel("Time (s)")
  plt.ylabel("Normalized Amplitude")
  plt.xlim(zoom_start_sec, zoom_end_sec)  # Zoom in on the time range
  plt.legend()
  plt.grid()
  plt.show()

  # Plot 2: Negative (Non-QRS) Segments
  plt.figure(figsize=(12, 4))
  plt.plot(time_axis, normalized_signal, label="ECG Signal", color="blue")

  # Highlight negative (non-QRS) windows in yellow (only within the zoom range)
  for start, end in negative_windows_zoom:
      plt.axvspan(start / G_fs, end / G_fs, color="yellow", alpha=0.3, label="Non-QRS Segment" if start == negative_windows_zoom[0][0] else "")
      #plt.vlines(start / G_fs, ymin=np.min(normalized_signal), ymax=np.max(normalized_signal), color="green", linestyle="dashed", alpha=0.6, label="Segment Start")

  plt.title(f"Negative (Non-QRS) Segments (Window Size: {G_window_size} samples, Overlap: {G_overlap} samples)")
  plt.xlabel("Time (s)")
  plt.ylabel("Normalized Amplitude")
  plt.xlim(zoom_start_sec, zoom_end_sec)  # Zoom in on the time range
  plt.legend()
  plt.grid()
  plt.show()

# %% [markdown]
# ## 1-4. traitement sigments

# %%
def clean_double_t_annotations(annotation):
    """
    Process annotation to merge consecutive 't' symbols into one at the midpoint.
    """
    new_samples = []
    new_symbols = []

    i = 0
    while i < len(annotation.symbol):
        sym = annotation.symbol[i]

        # Check for 't' followed by another 't'
        if sym == 't' and i + 1 < len(annotation.symbol) and annotation.symbol[i + 1] == 't':
            # Merge the two into one 't' at the midpoint
            mid_sample = int((annotation.sample[i] + annotation.sample[i + 1]) / 2)
            new_samples.append(mid_sample)
            new_symbols.append('t')
            i += 2  # Skip the next 't'
        else:
            new_samples.append(annotation.sample[i])
            new_symbols.append(annotation.symbol[i])
            i += 1

    # Return cleaned annotation
    from wfdb import Annotation
    return Annotation(record_name=annotation.record_name,
                      extension=annotation.extension,
                      sample=np.array(new_samples),
                      symbol=new_symbols,
                      aux_note=annotation.aux_note if hasattr(annotation, 'aux_note') else None)

# %%
def remove_consecutive_ones(segment_labels, segmented_signal, segment_starts):
    filtered_labels = []
    filtered_signal = []
    filtered_starts = []

    i = 0


    while i < len(segment_labels)-1:
        if segment_labels[i] == 1:
            # Find the range of consecutive ones
            start = i
            while i + 1 < len(segment_labels) and segment_labels[i + 1] == 1:
                i += 1
            end = i

            # Compute the middle index of the block
            mid = (start + end) // 2
            #mid =  end


            # Keep only the middle one
            filtered_labels.append(segment_labels[mid])
            filtered_signal.append(segmented_signal[mid])
            filtered_starts.append(segment_starts[mid])

        else:
            # Keep zeros as they are
            filtered_labels.append(segment_labels[i])
            filtered_signal.append(segmented_signal[i])
            filtered_starts.append(segment_starts[i])

        i += 1  # Move to the next segment

    return filtered_labels, filtered_signal, filtered_starts

# %%
def trim_to_ones(segment_labels, segmented_signal, segment_starts):
    # Find indices of all the '1's
    ones_indices = [i for i, label in enumerate(segment_labels) if label == 1]

    if not ones_indices:
        # No '1's found, return empty lists
        return [], [], []

    # Determine start and end range to keep
    first_one = ones_indices[0]
    last_one = ones_indices[-1]

    # Slice the arrays to keep only data between first and last 1 (inclusive)
    filtered_labels = segment_labels[first_one:last_one + 1]
    filtered_signal = segmented_signal[first_one:last_one + 1]
    filtered_starts = segment_starts[first_one:last_one + 1]

    return filtered_labels, filtered_signal, filtered_starts

# %%
def remove_touching_negatives(segment_labels, segmented_signal, segment_starts):
    new_labels = segment_labels[:]  # Copy original lists
    new_signal = segmented_signal[:]
    new_starts = segment_starts[:]

    step = G_window_size - G_overlap  # Compute the step size
    num_windows = max(1, round(G_window_size / step))-1 # Number of windows to remove (ensure at least 1)
    to_remove = set()  # Indices to remove

    for i, label in enumerate(segment_labels):
        if label == 1:  # If it's a positive window
            # Mark 4 windows before and after for removal
            for j in range(max(0, i - num_windows), min(len(segment_labels), i + num_windows + 1)):
                if segment_labels[j] == 0:  # Only remove negatives
                    to_remove.add(j)

    # Remove marked indices
    new_labels = [label for i, label in enumerate(segment_labels) if i not in to_remove]
    new_signal = [signal for i, signal in enumerate(segmented_signal) if i not in to_remove]
    new_starts = [start for i, start in enumerate(segment_starts) if i not in to_remove]

    return new_labels, new_signal, new_starts

# %%
import random

def balance_classes(segment_labels, segmented_signal, segment_starts):
    # Count positive and negative instances
    num_positives = sum(1 for label in segment_labels if label == 1)
    num_negatives = sum(1 for label in segment_labels if label == 0)

    # If negatives are already balanced, return as is
    if num_negatives <= num_positives:
        return segment_labels, segmented_signal, segment_starts

    # Get indices of negative samples
    negative_indices = [i for i, label in enumerate(segment_labels) if label == 0]

    # Randomly select indices to remove
    num_to_remove = num_negatives - num_positives
    indices_to_remove = set(random.sample(negative_indices, num_to_remove))

    # Remove selected negatives while keeping lists synchronized
    new_labels = [label for i, label in enumerate(segment_labels) if i not in indices_to_remove]
    new_signal = [signal for i, signal in enumerate(segmented_signal) if i not in indices_to_remove]
    new_starts = [start for i, start in enumerate(segment_starts) if i not in indices_to_remove]

    return new_labels, new_signal, new_starts

# %%
import numpy as np
import matplotlib.pyplot as plt
def display_segment(normalized_signal,segment_labels,segment_starts,z_start,z_end):
  # Define sampling rate

  # Define zoom window in **seconds**
  zoom_start_sec = z_start   # Start time in seconds
  zoom_end_sec = z_end     # End time in seconds

  # Convert zoom window from seconds to samples
  zoom_start = zoom_start_sec * G_fs  # Convert to sample index
  zoom_end = zoom_end_sec * G_fs      # Convert to sample index

  # Function to filter windows within the zoom range (in sample indices)
  def filter_windows_in_zoom(windows, zoom_start, zoom_end):
      """Filter windows that fall within the zoom range in samples."""
      return [(start, end) for start, end in windows if start < zoom_end and end > zoom_start]

  # Identify segment start and end in samples
  positive_windows = [(segment_starts[i], segment_starts[i] + G_window_size) for i in range(len(segment_labels)) if segment_labels[i] == 1]
  negative_windows = [(segment_starts[i], segment_starts[i] + G_window_size) for i in range(len(segment_labels)) if segment_labels[i] == 0]
  print("Number of positive (QRS) segments:", len(positive_windows))
  print("Number of negative (non-QRS) segments:", len(negative_windows))
  # Filter positive and negative windows within the zoom range
  positive_windows_zoom = filter_windows_in_zoom(positive_windows, zoom_start, zoom_end)
  negative_windows_zoom = filter_windows_in_zoom(negative_windows, zoom_start, zoom_end)

  # Create time axis in **seconds**
  time_axis = np.arange(len(normalized_signal)) / G_fs  # Convert samples to seconds

  # Plot 1: Positive (QRS) Segments
  plt.figure(figsize=(12, 4))
  plt.plot(time_axis, normalized_signal, label="ECG Signal", color="blue")

  # Highlight positive (QRS) windows in red (only within the zoom range)
  for start, end in positive_windows_zoom:
      plt.axvspan(start / G_fs, end / G_fs, color="red", alpha=0.3, label="QRS Segment" if start == positive_windows_zoom[0][0] else "")

  plt.title(f"Positive (QRS) Segments (Window Size: {G_window_size} samples, Overlap: {G_overlap} samples)")
  plt.xlabel("Time (s)")
  plt.ylabel("Normalized Amplitude")
  plt.xlim(zoom_start_sec, zoom_end_sec)  # Zoom in on the time range
  plt.legend()
  plt.grid()
  plt.show()

  # Plot 2: Negative (Non-QRS) Segments
  plt.figure(figsize=(12, 4))
  plt.plot(time_axis, normalized_signal, label="ECG Signal", color="blue")

  # Highlight negative (non-QRS) windows in yellow (only within the zoom range)
  for start, end in negative_windows_zoom:
      plt.axvspan(start / G_fs, end / G_fs, color="yellow", alpha=0.3, label="Non-QRS Segment" if start == negative_windows_zoom[0][0] else "")
      #plt.vlines(start / G_fs, ymin=np.min(normalized_signal), ymax=np.max(normalized_signal), color="green", linestyle="dashed", alpha=0.6, label="Segment Start")

  plt.title(f"Negative (Non-QRS) Segments (Window Size: {G_window_size} samples, Overlap: {G_overlap} samples)")
  plt.xlabel("Time (s)")
  plt.ylabel("Normalized Amplitude")
  plt.xlim(zoom_start_sec, zoom_end_sec)  # Zoom in on the time range
  plt.legend()
  plt.grid()
  plt.show()

# %% [markdown]
# # 2- preparing signals

# %%
import wfdb
import numpy as np
from scipy.signal import resample

import wfdb
import numpy as np
from scipy.signal import resample

# Define record directories
db_paths = {
    'ludb': '/content/physionet.org/files/ludb/1.0.1/',
    #'mitdb': '/content/physionet.org/files/mitdb/1.0.0/',
    'qtdb': '/content/physionet.org/files/qtdb/1.0.0/'
}

# Fetch record lists
record_lists = {
    db: wfdb.get_record_list(db) for db in db_paths
}

# Initialize accumulators
all_segments = []
all_segment_labels = []
all_segment_starts = []

# Process all records in all databases
for db_name, record_dir in db_paths.items():
    for record_name in record_lists[db_name]:
        print(f"Processing record: {record_name} from {db_name}")

        # Load signal
        record = wfdb.rdrecord(record_dir + record_name)
        try:
          if db_name == 'ludb' :
            annotation = wfdb.rdann(record_dir + record_name, 'i')
          else :
            annotation = wfdb.rdann(record_dir + record_name, 'pu0')
        except:
            print(f"No annotation found for {record_name}, skipping.")
            continue
        annotation = clean_double_t_annotations(annotation)
        ecg_signal = record.p_signal[:, 0]
        G_fs = record.fs

        time_axis = np.arange(0, len(ecg_signal)) / G_fs

        # Apply bandpass filter and smoothing
        filtered_signal = bandpass_filter(ecg_signal, 1000)
        smoothed_signal = smooth_signal(filtered_signal, window_size=5)

        # Normalize and segment
        normalized_signal = normalize_signal(smoothed_signal)

        # Extract annotation labels (adjust if needed for LUDB/QTDB)
        qrs_symbols = ['t']
        qrs_indices = [s for s, sym in zip(annotation.sample, annotation.symbol) if sym in qrs_symbols]

        if G_fs != 360:
            normalized_signal = resample_signal(normalized_signal, original_fs=G_fs, target_fs=360)
            qrs_indices = [adjust_annotation(point, original_fs=G_fs, target_fs=360) for point in qrs_indices]
            G_fs = 360

        # Segment the normalized signal
        segmented_signal, segment_starts = segment_signal(normalized_signal, window_size=G_window_size, overlap=G_overlap)


        # Label and clean
        segment_labels = label_segments(normalized_signal, segmented_signal, segment_starts, qrs_indices, q_offset=G_q_offset, window_size=G_window_size, overlap=G_overlap)
        segment_labels, segmented_signal, segment_starts = remove_consecutive_ones(segment_labels, segmented_signal, segment_starts)
        segment_labels, segmented_signal, segment_starts = trim_to_ones(segment_labels, segmented_signal, segment_starts)
        segment_labels, segmented_signal, segment_starts = remove_touching_negatives(segment_labels, segmented_signal, segment_starts)
        #display_segment(normalized_signal,segment_labels,segment_starts,0,10)
        segment_labels, segmented_signal, segment_starts = balance_classes(segment_labels, segmented_signal, segment_starts)
        if record_name==record_lists[db_name][-1] or record_name==record_lists[db_name][0]:
          display_segment(normalized_signal,segment_labels,segment_starts,5,10)
        print(f"{record_name} positive: {np.sum(np.array(segment_labels) == 1)}, negative: {np.sum(np.array(segment_labels) == 0)}")

        '''
        np.savez("/content/drive/MyDrive/Final project/QRS detection/segments/"+record_name+" from "+db_name+" segment 70s 65o 33q.npz",
                segments=np.array(segmented_signal, dtype=object),
                labels=np.array(segment_labels),
                starts=np.array(segment_starts))
        '''
        # Store all data
        all_segments.extend(segmented_signal)
        all_segment_labels.extend(segment_labels)
        all_segment_starts.extend(segment_starts)

print(f"Total segments collected: {len(all_segments)}")
# Out:
# Processing record: data/1 from ludb
# Number of positive (QRS) segments: 5
# Number of negative (non-QRS) segments: 5
# data/1 positive: 5, negative: 5
# Processing record: data/2 from ludb
# data/2 positive: 8, negative: 8
# Processing record: data/3 from ludb
# data/3 positive: 8, negative: 8
# Processing record: data/4 from ludb
# data/4 positive: 8, negative: 8
# Processing record: data/5 from ludb
# data/5 positive: 6, negative: 6
# Processing record: data/6 from ludb
# data/6 positive: 6, negative: 6
# Processing record: data/7 from ludb
# data/7 positive: 7, negative: 7
# Processing record: data/8 from ludb
# data/8 positive: 9, negative: 9
# Processing record: data/9 from ludb
# data/9 positive: 8, negative: 8
# Processing record: data/10 from ludb
# data/10 positive: 7, negative: 7
# Processing record: data/11 from ludb
# data/11 positive: 7, negative: 7
# Processing record: data/12 from ludb
# data/12 positive: 6, negative: 6
# Processing record: data/13 from ludb
# data/13 positive: 6, negative: 6
# Processing record: data/14 from ludb
# data/14 positive: 11, negative: 11
# Processing record: data/15 from ludb
# data/15 positive: 7, negative: 7
# Processing record: data/16 from ludb
# data/16 positive: 9, negative: 9
# Processing record: data/17 from ludb
# data/17 positive: 9, negative: 9
# Processing record: data/18 from ludb
# data/18 positive: 10, negative: 10
# Processing record: data/19 from ludb
# data/19 positive: 7, negative: 7
# Processing record: data/20 from ludb
# data/20 positive: 7, negative: 7
# Processing record: data/21 from ludb
# data/21 positive: 9, negative: 9
# Processing record: data/22 from ludb
# data/22 positive: 10, negative: 10
# Processing record: data/23 from ludb
# data/23 positive: 7, negative: 7
# Processing record: data/24 from ludb
# data/24 positive: 6, negative: 6
# Processing record: data/25 from ludb
# data/25 positive: 6, negative: 6
# Processing record: data/26 from ludb
# data/26 positive: 7, negative: 7
# Processing record: data/27 from ludb
# data/27 positive: 6, negative: 6
# Processing record: data/28 from ludb
# data/28 positive: 7, negative: 7
# Processing record: data/29 from ludb
# data/29 positive: 8, negative: 8
# Processing record: data/30 from ludb
# data/30 positive: 6, negative: 6
# Processing record: data/31 from ludb
# data/31 positive: 8, negative: 8
# Processing record: data/32 from ludb
# data/32 positive: 8, negative: 8
# Processing record: data/33 from ludb
# data/33 positive: 7, negative: 7
# Processing record: data/34 from ludb
# data/34 positive: 7, negative: 7
# Processing record: data/35 from ludb
# data/35 positive: 19, negative: 19
# Processing record: data/36 from ludb
# data/36 positive: 7, negative: 7
# Processing record: data/37 from ludb
# data/37 positive: 9, negative: 9
# Processing record: data/38 from ludb
# data/38 positive: 13, negative: 13
# Processing record: data/39 from ludb
# data/39 positive: 6, negative: 6
# Processing record: data/40 from ludb
# data/40 positive: 8, negative: 8
# Processing record: data/41 from ludb
# data/41 positive: 5, negative: 5
# Processing record: data/42 from ludb
# data/42 positive: 7, negative: 7
# Processing record: data/43 from ludb
# data/43 positive: 7, negative: 7
# Processing record: data/44 from ludb
# data/44 positive: 8, negative: 8
# Processing record: data/45 from ludb
# data/45 positive: 7, negative: 7
# Processing record: data/46 from ludb
# data/46 positive: 7, negative: 7
# Processing record: data/47 from ludb
# data/47 positive: 4, negative: 4
# Processing record: data/48 from ludb
# data/48 positive: 6, negative: 6
# Processing record: data/49 from ludb
# data/49 positive: 7, negative: 7
# Processing record: data/50 from ludb
# data/50 positive: 8, negative: 8
# Processing record: data/51 from ludb
# data/51 positive: 7, negative: 7
# Processing record: data/52 from ludb
# data/52 positive: 8, negative: 8
# Processing record: data/53 from ludb
# data/53 positive: 8, negative: 8
# Processing record: data/54 from ludb
# data/54 positive: 6, negative: 6
# Processing record: data/55 from ludb
# data/55 positive: 7, negative: 7
# Processing record: data/56 from ludb
# data/56 positive: 10, negative: 10
# Processing record: data/57 from ludb
# data/57 positive: 12, negative: 12
# Processing record: data/58 from ludb
# data/58 positive: 9, negative: 9
# Processing record: data/59 from ludb
# data/59 positive: 5, negative: 5
# Processing record: data/60 from ludb
# data/60 positive: 7, negative: 7
# Processing record: data/61 from ludb
# data/61 positive: 8, negative: 8
# Processing record: data/62 from ludb
# data/62 positive: 8, negative: 8
# Processing record: data/63 from ludb
# data/63 positive: 9, negative: 9
# Processing record: data/64 from ludb
# data/64 positive: 8, negative: 8
# Processing record: data/65 from ludb
# data/65 positive: 11, negative: 11
# Processing record: data/66 from ludb
# data/66 positive: 5, negative: 5
# Processing record: data/67 from ludb
# data/67 positive: 6, negative: 6
# Processing record: data/68 from ludb
# data/68 positive: 8, negative: 8
# Processing record: data/69 from ludb
# data/69 positive: 10, negative: 10
# Processing record: data/70 from ludb
# data/70 positive: 12, negative: 12
# Processing record: data/71 from ludb
# data/71 positive: 7, negative: 7
# Processing record: data/72 from ludb
# data/72 positive: 7, negative: 7
# Processing record: data/73 from ludb
# data/73 positive: 7, negative: 7
# Processing record: data/74 from ludb
# data/74 positive: 8, negative: 8
# Processing record: data/75 from ludb
# data/75 positive: 8, negative: 8
# Processing record: data/76 from ludb
# data/76 positive: 10, negative: 10
# Processing record: data/77 from ludb
# data/77 positive: 9, negative: 9
# Processing record: data/78 from ludb
# data/78 positive: 7, negative: 7
# Processing record: data/79 from ludb
# data/79 positive: 7, negative: 7
# Processing record: data/80 from ludb
# data/80 positive: 10, negative: 10
# Processing record: data/81 from ludb
# data/81 positive: 10, negative: 10
# Processing record: data/82 from ludb
# data/82 positive: 6, negative: 6
# Processing record: data/83 from ludb
# data/83 positive: 9, negative: 9
# Processing record: data/84 from ludb
# data/84 positive: 7, negative: 7
# Processing record: data/85 from ludb
# data/85 positive: 9, negative: 9
# Processing record: data/86 from ludb
# data/86 positive: 11, negative: 11
# Processing record: data/87 from ludb
# data/87 positive: 11, negative: 11
# Processing record: data/88 from ludb
# data/88 positive: 11, negative: 11
# Processing record: data/89 from ludb
# data/89 positive: 9, negative: 9
# Processing record: data/90 from ludb
# data/90 positive: 7, negative: 7
# Processing record: data/91 from ludb
# data/91 positive: 10, negative: 10
# Processing record: data/92 from ludb
# data/92 positive: 13, negative: 13
# Processing record: data/93 from ludb
# data/93 positive: 7, negative: 7
# Processing record: data/94 from ludb
# data/94 positive: 9, negative: 9
# Processing record: data/95 from ludb
# data/95 positive: 8, negative: 8
# Processing record: data/96 from ludb
# data/96 positive: 11, negative: 11
# Processing record: data/97 from ludb
# data/97 positive: 7, negative: 7
# Processing record: data/98 from ludb
# data/98 positive: 7, negative: 7
# Processing record: data/99 from ludb
# data/99 positive: 11, negative: 11
# Processing record: data/100 from ludb
# data/100 positive: 8, negative: 8
# Processing record: data/101 from ludb
# data/101 positive: 10, negative: 10
# Processing record: data/102 from ludb
# data/102 positive: 8, negative: 8
# Processing record: data/103 from ludb
# data/103 positive: 13, negative: 13
# Processing record: data/104 from ludb
# data/104 positive: 8, negative: 8
# Processing record: data/105 from ludb
# data/105 positive: 10, negative: 10
# Processing record: data/106 from ludb
# data/106 positive: 11, negative: 11
# Processing record: data/107 from ludb
# data/107 positive: 7, negative: 7
# Processing record: data/108 from ludb
# data/108 positive: 10, negative: 10
# Processing record: data/109 from ludb
# data/109 positive: 14, negative: 14
# Processing record: data/110 from ludb
# data/110 positive: 12, negative: 12
# Processing record: data/111 from ludb
# data/111 positive: 7, negative: 7
# Processing record: data/112 from ludb
# data/112 positive: 13, negative: 13
# Processing record: data/113 from ludb
# data/113 positive: 7, negative: 7
# Processing record: data/114 from ludb
# data/114 positive: 13, negative: 13
# Processing record: data/115 from ludb
# data/115 positive: 7, negative: 7
# Processing record: data/116 from ludb
# data/116 positive: 13, negative: 13
# Processing record: data/117 from ludb
# data/117 positive: 13, negative: 13
# Processing record: data/118 from ludb
# data/118 positive: 8, negative: 8
# Processing record: data/119 from ludb
# data/119 positive: 7, negative: 7
# Processing record: data/120 from ludb
# data/120 positive: 7, negative: 7
# Processing record: data/121 from ludb
# data/121 positive: 14, negative: 14
# Processing record: data/122 from ludb
# data/122 positive: 7, negative: 7
# Processing record: data/123 from ludb
# data/123 positive: 8, negative: 8
# Processing record: data/124 from ludb
# data/124 positive: 6, negative: 6
# Processing record: data/125 from ludb
# data/125 positive: 6, negative: 6
# Processing record: data/126 from ludb
# data/126 positive: 8, negative: 8
# Processing record: data/127 from ludb
# data/127 positive: 3, negative: 3
# Processing record: data/128 from ludb
# data/128 positive: 6, negative: 6
# Processing record: data/129 from ludb
# data/129 positive: 7, negative: 7
# Processing record: data/130 from ludb
# data/130 positive: 6, negative: 6
# Processing record: data/131 from ludb
# data/131 positive: 7, negative: 7
# Processing record: data/132 from ludb
# data/132 positive: 7, negative: 7
# Processing record: data/133 from ludb
# data/133 positive: 6, negative: 6
# Processing record: data/134 from ludb
# data/134 positive: 5, negative: 5
# Processing record: data/135 from ludb
# data/135 positive: 8, negative: 8
# Processing record: data/136 from ludb
# data/136 positive: 12, negative: 12
# Processing record: data/137 from ludb
# data/137 positive: 8, negative: 8
# Processing record: data/138 from ludb
# data/138 positive: 7, negative: 7
# Processing record: data/139 from ludb
# data/139 positive: 9, negative: 9
# Processing record: data/140 from ludb
# data/140 positive: 10, negative: 10
# Processing record: data/141 from ludb
# data/141 positive: 7, negative: 7
# Processing record: data/142 from ludb
# data/142 positive: 9, negative: 9
# Processing record: data/143 from ludb
# data/143 positive: 11, negative: 11
# Processing record: data/144 from ludb
# data/144 positive: 8, negative: 8
# Processing record: data/145 from ludb
# data/145 positive: 8, negative: 8
# Processing record: data/146 from ludb
# data/146 positive: 7, negative: 7
# Processing record: data/147 from ludb
# data/147 positive: 7, negative: 7
# Processing record: data/148 from ludb
# data/148 positive: 9, negative: 9
# Processing record: data/149 from ludb
# data/149 positive: 8, negative: 8
# Processing record: data/150 from ludb
# data/150 positive: 7, negative: 7
# Processing record: data/151 from ludb
# data/151 positive: 9, negative: 9
# Processing record: data/152 from ludb
# data/152 positive: 8, negative: 8
# Processing record: data/153 from ludb
# data/153 positive: 7, negative: 7
# Processing record: data/154 from ludb
# data/154 positive: 8, negative: 8
# Processing record: data/155 from ludb
# data/155 positive: 7, negative: 7
# Processing record: data/156 from ludb
# data/156 positive: 6, negative: 6
# Processing record: data/157 from ludb
# data/157 positive: 6, negative: 6
# Processing record: data/158 from ludb
# data/158 positive: 7, negative: 7
# Processing record: data/159 from ludb
# data/159 positive: 8, negative: 8
# Processing record: data/160 from ludb
# data/160 positive: 4, negative: 4
# Processing record: data/161 from ludb
# data/161 positive: 7, negative: 7
# Processing record: data/162 from ludb
# data/162 positive: 9, negative: 9
# Processing record: data/163 from ludb
# data/163 positive: 9, negative: 9
# Processing record: data/164 from ludb
# data/164 positive: 8, negative: 8
# Processing record: data/165 from ludb
# data/165 positive: 8, negative: 8
# Processing record: data/166 from ludb
# data/166 positive: 7, negative: 7
# Processing record: data/167 from ludb
# data/167 positive: 8, negative: 8
# Processing record: data/168 from ludb
# data/168 positive: 7, negative: 7
# Processing record: data/169 from ludb
# data/169 positive: 6, negative: 6
# Processing record: data/170 from ludb
# data/170 positive: 6, negative: 6
# Processing record: data/171 from ludb
# data/171 positive: 9, negative: 9
# Processing record: data/172 from ludb
# data/172 positive: 6, negative: 6
# Processing record: data/173 from ludb
# data/173 positive: 11, negative: 11
# Processing record: data/174 from ludb
# data/174 positive: 7, negative: 7
# Processing record: data/175 from ludb
# data/175 positive: 9, negative: 9
# Processing record: data/176 from ludb
# data/176 positive: 7, negative: 7
# Processing record: data/177 from ludb
# data/177 positive: 11, negative: 11
# Processing record: data/178 from ludb
# data/178 positive: 11, negative: 11
# Processing record: data/179 from ludb
# data/179 positive: 7, negative: 7
# Processing record: data/180 from ludb
# data/180 positive: 9, negative: 9
# Processing record: data/181 from ludb
# data/181 positive: 7, negative: 7
# Processing record: data/182 from ludb
# data/182 positive: 11, negative: 11
# Processing record: data/183 from ludb
# data/183 positive: 10, negative: 10
# Processing record: data/184 from ludb
# data/184 positive: 8, negative: 8
# Processing record: data/185 from ludb
# data/185 positive: 12, negative: 12
# Processing record: data/186 from ludb
# data/186 positive: 10, negative: 10
# Processing record: data/187 from ludb
# data/187 positive: 8, negative: 8
# Processing record: data/188 from ludb
# data/188 positive: 13, negative: 13
# Processing record: data/189 from ludb
# data/189 positive: 7, negative: 7
# Processing record: data/190 from ludb
# data/190 positive: 11, negative: 11
# Processing record: data/191 from ludb
# data/191 positive: 7, negative: 7
# Processing record: data/192 from ludb
# data/192 positive: 7, negative: 7
# Processing record: data/193 from ludb
# data/193 positive: 8, negative: 8
# Processing record: data/194 from ludb
# data/194 positive: 7, negative: 7
# Processing record: data/195 from ludb
# data/195 positive: 8, negative: 8
# Processing record: data/196 from ludb
# data/196 positive: 9, negative: 9
# Processing record: data/197 from ludb
# data/197 positive: 10, negative: 10
# Processing record: data/198 from ludb
# data/198 positive: 7, negative: 7
# Processing record: data/199 from ludb
# data/199 positive: 7, negative: 7
# Processing record: data/200 from ludb
# Number of positive (QRS) segments: 8
# Number of negative (non-QRS) segments: 8
# data/200 positive: 8, negative: 8
# Processing record: sel100 from qtdb
# Number of positive (QRS) segments: 1122
# Number of negative (non-QRS) segments: 1122
# sel100 positive: 1122, negative: 1122
# Processing record: sel102 from qtdb
# sel102 positive: 1087, negative: 1087
# Processing record: sel103 from qtdb
# sel103 positive: 1047, negative: 1047
# Processing record: sel104 from qtdb
# sel104 positive: 1105, negative: 1105
# Processing record: sel114 from qtdb
# sel114 positive: 854, negative: 854
# Processing record: sel116 from qtdb
# sel116 positive: 1183, negative: 1183
# Processing record: sel117 from qtdb
# sel117 positive: 765, negative: 765
# Processing record: sel123 from qtdb
# sel123 positive: 751, negative: 751
# Processing record: sel14046 from qtdb
# sel14046 positive: 1258, negative: 1258
# Processing record: sel14157 from qtdb
# sel14157 positive: 1079, negative: 1079
# Processing record: sel14172 from qtdb
# sel14172 positive: 637, negative: 637
# Processing record: sel15814 from qtdb
# sel15814 positive: 1011, negative: 1011
# Processing record: sel16265 from qtdb
# sel16265 positive: 1030, negative: 1030
# Processing record: sel16272 from qtdb
# sel16272 positive: 849, negative: 849
# Processing record: sel16273 from qtdb
# sel16273 positive: 1110, negative: 1110
# Processing record: sel16420 from qtdb
# sel16420 positive: 1062, negative: 1062
# Processing record: sel16483 from qtdb
# sel16483 positive: 1084, negative: 1084
# Processing record: sel16539 from qtdb
# sel16539 positive: 919, negative: 919
# Processing record: sel16773 from qtdb
# sel16773 positive: 1006, negative: 1006
# Processing record: sel16786 from qtdb
# sel16786 positive: 924, negative: 924
# Processing record: sel16795 from qtdb
# sel16795 positive: 759, negative: 759
# Processing record: sel17152 from qtdb
# sel17152 positive: 1615, negative: 1615
# Processing record: sel17453 from qtdb
# sel17453 positive: 1045, negative: 1045
# Processing record: sel213 from qtdb
# sel213 positive: 1631, negative: 1631
# Processing record: sel221 from qtdb
# sel221 positive: 1215, negative: 1215
# Processing record: sel223 from qtdb
# sel223 positive: 1299, negative: 1299
# Processing record: sel230 from qtdb
# sel230 positive: 1063, negative: 1063
# Processing record: sel231 from qtdb
# sel231 positive: 729, negative: 729
# Processing record: sel232 from qtdb
# sel232 positive: 874, negative: 874
# Processing record: sel233 from qtdb
# sel233 positive: 1497, negative: 1497
# Processing record: sel30 from qtdb
# sel30 positive: 1012, negative: 1012
# Processing record: sel301 from qtdb
# sel301 positive: 1347, negative: 1347
# Processing record: sel302 from qtdb
# sel302 positive: 1499, negative: 1499
# Processing record: sel306 from qtdb
# sel306 positive: 1039, negative: 1039
# Processing record: sel307 from qtdb
# sel307 positive: 851, negative: 851
# Processing record: sel308 from qtdb
# sel308 positive: 1289, negative: 1289
# Processing record: sel31 from qtdb
# sel31 positive: 842, negative: 842
# Processing record: sel310 from qtdb
# sel310 positive: 1630, negative: 1630
# Processing record: sel32 from qtdb
# sel32 positive: 1189, negative: 1189
# Processing record: sel33 from qtdb
# sel33 positive: 523, negative: 523
# Processing record: sel34 from qtdb
# sel34 positive: 896, negative: 896
# Processing record: sel35 from qtdb
# sel35 positive: 863, negative: 863
# Processing record: sel36 from qtdb
# sel36 positive: 930, negative: 930
# Processing record: sel37 from qtdb
# sel37 positive: 649, negative: 649
# Processing record: sel38 from qtdb
# sel38 positive: 1559, negative: 1559
# Processing record: sel39 from qtdb
# sel39 positive: 1162, negative: 1162
# Processing record: sel40 from qtdb
# sel40 positive: 1067, negative: 1067
# Processing record: sel41 from qtdb
# sel41 positive: 1204, negative: 1204
# Processing record: sel42 from qtdb
# sel42 positive: 1243, negative: 1243
# Processing record: sel43 from qtdb
# sel43 positive: 582, negative: 582
# Processing record: sel44 from qtdb
# sel44 positive: 1174, negative: 1174
# Processing record: sel45 from qtdb
# sel45 positive: 741, negative: 741
# Processing record: sel46 from qtdb
# sel46 positive: 839, negative: 839
# Processing record: sel47 from qtdb
# sel47 positive: 884, negative: 884
# Processing record: sel48 from qtdb
# sel48 positive: 1394, negative: 1394
# Processing record: sel49 from qtdb
# sel49 positive: 825, negative: 825
# Processing record: sel50 from qtdb
# sel50 positive: 655, negative: 655
# Processing record: sel51 from qtdb
# sel51 positive: 302, negative: 302
# Processing record: sel52 from qtdb
# sel52 positive: 1398, negative: 1398
# Processing record: sel803 from qtdb
# sel803 positive: 1025, negative: 1025
# Processing record: sel808 from qtdb
# sel808 positive: 902, negative: 902
# Processing record: sel811 from qtdb
# sel811 positive: 700, negative: 700
# Processing record: sel820 from qtdb
# sel820 positive: 1156, negative: 1156
# Processing record: sel821 from qtdb
# sel821 positive: 1550, negative: 1550
# Processing record: sel840 from qtdb
# sel840 positive: 1176, negative: 1176
# Processing record: sel847 from qtdb
# sel847 positive: 799, negative: 799
# Processing record: sel853 from qtdb
# sel853 positive: 1110, negative: 1110
# Processing record: sel871 from qtdb
# sel871 positive: 915, negative: 915
# Processing record: sel872 from qtdb
# sel872 positive: 988, negative: 988
# Processing record: sel873 from qtdb
# sel873 positive: 857, negative: 857
# Processing record: sel883 from qtdb
# sel883 positive: 890, negative: 890
# Processing record: sel891 from qtdb
# sel891 positive: 1263, negative: 1263
# Processing record: sele0104 from qtdb
# sele0104 positive: 801, negative: 801
# Processing record: sele0106 from qtdb
# sele0106 positive: 858, negative: 858
# Processing record: sele0107 from qtdb
# sele0107 positive: 812, negative: 812
# Processing record: sele0110 from qtdb
# sele0110 positive: 870, negative: 870
# Processing record: sele0111 from qtdb
# sele0111 positive: 904, negative: 904
# Processing record: sele0112 from qtdb
# sele0112 positive: 682, negative: 682
# Processing record: sele0114 from qtdb
# sele0114 positive: 693, negative: 693
# Processing record: sele0116 from qtdb
# sele0116 positive: 555, negative: 555
# Processing record: sele0121 from qtdb
# sele0121 positive: 1429, negative: 1429
# Processing record: sele0122 from qtdb
# sele0122 positive: 1412, negative: 1412
# Processing record: sele0124 from qtdb
# sele0124 positive: 1118, negative: 1118
# Processing record: sele0126 from qtdb
# sele0126 positive: 944, negative: 944
# Processing record: sele0129 from qtdb
# sele0129 positive: 650, negative: 650
# Processing record: sele0133 from qtdb
# sele0133 positive: 824, negative: 824
# Processing record: sele0136 from qtdb
# sele0136 positive: 805, negative: 805
# Processing record: sele0166 from qtdb
# sele0166 positive: 810, negative: 810
# Processing record: sele0170 from qtdb
# sele0170 positive: 895, negative: 895
# Processing record: sele0203 from qtdb
# sele0203 positive: 1243, negative: 1243
# Processing record: sele0210 from qtdb
# sele0210 positive: 1061, negative: 1061
# Processing record: sele0211 from qtdb
# sele0211 positive: 1573, negative: 1573
# Processing record: sele0303 from qtdb
# sele0303 positive: 1042, negative: 1042
# Processing record: sele0405 from qtdb
# sele0405 positive: 1213, negative: 1213
# Processing record: sele0406 from qtdb
# sele0406 positive: 957, negative: 957
# Processing record: sele0409 from qtdb
# sele0409 positive: 1730, negative: 1730
# Processing record: sele0411 from qtdb
# sele0411 positive: 1201, negative: 1201
# Processing record: sele0509 from qtdb
# sele0509 positive: 1025, negative: 1025
# Processing record: sele0603 from qtdb
# sele0603 positive: 867, negative: 867
# Processing record: sele0604 from qtdb
# sele0604 positive: 1029, negative: 1029
# Processing record: sele0606 from qtdb
# sele0606 positive: 1441, negative: 1441
# Processing record: sele0607 from qtdb
# sele0607 positive: 1180, negative: 1180
# Processing record: sele0609 from qtdb
# sele0609 positive: 1125, negative: 1125
# Processing record: sele0612 from qtdb
# sele0612 positive: 749, negative: 749
# Processing record: sele0704 from qtdb
# Number of positive (QRS) segments: 1093
# Number of negative (non-QRS) segments: 1093
# sele0704 positive: 1093, negative: 1093
# Total segments collected: 219524

# %%
# Fetch record lists
record_lists = ["sel31",
                "sel32",
                "sel33",
                "sel34",
                "sel35",
                "sel36",
                "sel37",
                "sel38",
                "sel39",
                "sel40",
                "sel41",
                "sel42",
                "sel43",
                "sel44",
                "sel45",
                "sel46",
                "sel47",
                "sel48",
                "sel49",
                "sel50",
                "sel51",
                "sel52"]
db_name = 'qtdb'
record_dir = '/content/physionet.org/files/qtdb/1.0.0/'

for record_name in record_lists:
        print(f"Processing record: {record_name} from {db_name}")

        # Load signal
        record = wfdb.rdrecord(record_dir + record_name)
        try:
            annotation = wfdb.rdann(record_dir + record_name, 'pu0')
        except:
            print(f"No annotation found for {record_name}, skipping.")
            continue

        ecg_signal = record.p_signal[:, 0]P
        G_fs = record.fs

        time_axis = np.arange(0, len(ecg_signal)) / G_fs

        # Apply bandpass filter and smoothing
        filtered_signal = bandpass_filter(ecg_signal, 1000)
        smoothed_signal = smooth_signal(filtered_signal, window_size=5)

        # Normalize and segment
        normalized_signal = normalize_signal(smoothed_signal)

        # Extract annotation labels (adjust if needed for LUDB/QTDB)
        qrs_symbols = ['N', 'L', 'R', 'V', 'A']
        qrs_indices = [s for s, sym in zip(annotation.sample, annotation.symbol) if sym in qrs_symbols]

        if G_fs != 360:
            normalized_signal = resample_signal(normalized_signal, original_fs=G_fs, target_fs=360)
            qrs_indices = [adjust_annotation(point, original_fs=G_fs, target_fs=360) for point in qrs_indices]
            G_fs = 360

        # Segment the normalized signal
        segmented_signal, segment_starts = segment_signal(normalized_signal, window_size=G_window_size, overlap=G_overlap)


        # Label and clean
        segment_labels = label_segments(normalized_signal, segmented_signal, segment_starts, qrs_indices, q_offset=G_q_offset, window_size=G_window_size, overlap=G_overlap)
        segment_labels, segmented_signal, segment_starts = remove_consecutive_ones(segment_labels, segmented_signal, segment_starts)
        segment_labels, segmented_signal, segment_starts = trim_to_ones(segment_labels, segmented_signal, segment_starts)
        segment_labels, segmented_signal, segment_starts = remove_touching_negatives(segment_labels, segmented_signal, segment_starts)
        #display_segment(normalized_signal,segment_labels,segment_starts,0,10)
        segment_labels, segmented_signal, segment_starts = balance_classes(segment_labels, segmented_signal, segment_starts)

        print(f"{record_name} positive: {np.sum(np.array(segment_labels) == 1)}, negative: {np.sum(np.array(segment_labels) == 0)}")

        '''
        np.savez("/content/drive/MyDrive/Final project/QRS detection/segments/"+record_name+" from "+db_name+" segment 70s 65o 33q.npz",
                segments=np.array(segmented_signal, dtype=object),
                labels=np.array(segment_labels),
                starts=np.array(segment_starts))
        '''
        # Store all data
        all_segments.extend(segmented_signal)
        all_segment_labels.extend(segment_labels)
        all_segment_starts.extend(segment_starts)

# %%
print(f"Total segments collected: {len(all_segments)}")
# Out:
# Total segments collected: 219524

# %%
import numpy as np

# save segments

np.savez("T waves ludb qtdb segments 360hz 40s 30o 14q",
         segments=np.array(all_segments, dtype=object),
         labels=np.array(all_segment_labels),
         starts=np.array(all_segment_starts))

# !cp '/content/T waves ludb qtdb segments 360hz 40s 30o 14q.npz' '/content/drive/MyDrive/Final project/QRS detection/segments/T waves ludb qtdb segments 360hz 40s 30o 14q.npz'

# %%
import numpy as np
## load segments
data = np.load("/content/drive/MyDrive/Final project/QRS detection/segments/P waves ludb qtdb segments 360hz 40s 30o 14q.npz", allow_pickle=True)
#
## Extract lists
all_segments = data["segments"].tolist()
all_segment_labels = data["labels"].tolist()
all_segment_starts = data["starts"].tolist()
#
print("Data loaded successfully!")
print(len(all_segments))
print(len(all_segment_labels))
print(len(all_segment_starts))
# Out:
# Data loaded successfully!
# 197036
# 197036
# 197036

# %% [markdown]
# # 3-data Traitement

# %%
segment_labels = np.array(all_segment_labels)
segmented_signal = np.array(all_segments)
segment_starts = np.array(all_segment_starts)

# %% [markdown]
# ## A. Shuffle and Reshape Data

# %%
from sklearn.utils import shuffle
import numpy as np

# Shuffle the data
all_segments, all_labels = shuffle(segmented_signal, segment_labels, random_state=42)
# Reshape to (num_samples, window_length, 1)
all_segments = all_segments.reshape(all_segments.shape[0], all_segments.shape[1], 1)
print("Reshaped data for CNN+LSTM:", all_segments.shape)
# Ensure all_labels is a 1D array
all_labels = np.array(all_labels).flatten()  # Convert to 1D array if it's not already
print("Shape of all_labels:", all_labels.shape)

# Separate positive and negative segments
positive_segments = all_segments[all_labels == 1]  # Index using the 1D boolean array
negative_segments = all_segments[all_labels == 0]

print ("positive segments:",positive_segments.shape)
print ("negative segments:",negative_segments.shape)


# Combine balanced positive and negative segments
balanced_segments = np.concatenate([positive_segments, negative_segments])
balanced_labels = np.concatenate([np.ones(len(positive_segments)), np.zeros(len(negative_segments))])
print(len(balanced_segments),len(balanced_labels))
# Shuffle the balanced dataset
balanced_segments, balanced_labels = shuffle(balanced_segments, balanced_labels, random_state=42)

# Reshape to (num_samples, window_length, 1)
balanced_segments = balanced_segments.reshape(balanced_segments.shape[0], balanced_segments.shape[1], 1)
print("Balanced data shape:", balanced_segments.shape)
# Out:
# Reshaped data for CNN+LSTM: (219524, 65, 1)
# Shape of all_labels: (219524,)
# positive segments: (109762, 65, 1)
# negative segments: (109762, 65, 1)
# 219524 219524
# Balanced data shape: (219524, 65, 1)

# %% [markdown]
# ## B. Split

# %%
from sklearn.model_selection import train_test_split

# Split into training, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(balanced_segments, balanced_labels, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

print("Train:", X_train.shape, y_train.shape)
print("Validation:", X_val.shape, y_val.shape)
print("Test:", X_test.shape, y_test.shape)
# Out:
# Train: (131714, 65, 1) (131714,)
# Validation: (43905, 65, 1) (43905,)
# Test: (43905, 65, 1) (43905,)

# %%
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
# Out:
# Shape of X_train: (131714, 65, 1)
# Shape of y_train: (131714,)

# %%
# Reshape y_train, y_val, and y_test to match the model's output shape
y_train = y_train.reshape(-1, 1, 1)  # Shape: [num_samples, 1, 1]
y_val = y_val.reshape(-1, 1, 1)      # Shape: [num_samples, 1, 1]
y_test = y_test.reshape(-1, 1, 1)    # Shape: [num_samples, 1, 1]

# Verify shapes
print("Train:", X_train.shape, y_train.shape)
print("Validation:", X_val.shape, y_val.shape)
print("Test:", X_test.shape, y_test.shape)
# Out:
# Train: (131714, 65, 1) (131714, 1, 1)
# Validation: (43905, 65, 1) (43905, 1, 1)
# Test: (43905, 65, 1) (43905, 1, 1)

# %%
import numpy as np

X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
print("NaN in X_train:", np.isnan(X_train).any())
print("Inf in X_train:", np.isinf(X_train).any())
print("NaN in y_train:", np.isnan(y_train).any())
print("Inf in y_train:", np.isinf(y_train).any())
# Out:
# NaN in X_train: False
# Inf in X_train: False
# NaN in y_train: False
# Inf in y_train: False

# %% [markdown]
# # 4- Build the Hybrid CNN + LSTM Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv1D, MaxPooling1D, BatchNormalization, Flatten, Reshape,
    Bidirectional, LSTM, Dense, Dropout, TimeDistributed
)
# Parameters
window_length = G_window_size  # Fixed window length (e.g., 250 samples)
input_shape = (window_length, 1)  # Input shape: (batch_size, 250, 1)

# Define the CNN + LSTM model architecture
model = Sequential()

# --- CNN layers ---
# Input shape: (250, 1)
model.add(Conv1D(filters=32, kernel_size=5, activation='relu', input_shape=input_shape))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())

# Second Conv1D layer
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())

# Third Conv1D layer
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(BatchNormalization())

# --- Flatten and reshape for LSTM ---
model.add(Flatten())

# Automatically calculate the flattened shape
flattened_shape = model.output_shape[1]  # Get the shape after Flatten
print(f"Flattened shape: {flattened_shape}")

# Reshape to (timesteps, features) for LSTM
model.add(Reshape((1, flattened_shape)))  # Reshape dynamically

model.add(Bidirectional(LSTM(units=100, return_sequences=False)))  # No need for return_sequences=True

# --- Fully Connected Layers ---
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.5))

# --- Output Layer ---
model.add(Dense(1, activation='sigmoid'))  # Binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()# Binary classification (QRS vs. non-QRS)
# Out:
# Flattened shape: 768
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_6 (Conv1D)                    │ (None, 61, 32)              │             192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_6 (MaxPooling1D)       │ (None, 30, 32)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 30, 32)              │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_7 (Conv1D)                    │ (None, 28, 64)              │           6,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_7 (MaxPooling1D)       │ (None, 14, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 14, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_8 (Conv1D)                    │ (None, 12, 128)             │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_8 (MaxPooling1D)       │ (None, 6, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 6, 128)              │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 768)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_2 (Reshape)                  │ (None, 1, 768)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_2 (Bidirectional)      │ (None, 200)                 │         695,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 50)                  │          10,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 737,301 (2.81 MB)
#  Trainable params: 736,853 (2.81 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# # 5- Train the Model

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

# Train Model
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, batch_size=64,
          callbacks=[early_stopping, lr_scheduler])
# Out:
# Epoch 1/10
# 2059/2059 ━━━━━━━━━━━━━━━━━━━━ 68s 30ms/step - accuracy: 0.9281 - loss: 0.1878 - val_accuracy: 0.9544 - val_loss: 0.1241 - learning_rate: 0.0010
# Epoch 2/10
# 2059/2059 ━━━━━━━━━━━━━━━━━━━━ 85s 31ms/step - accuracy: 0.9617 - loss: 0.1080 - val_accuracy: 0.9649 - val_loss: 0.0970 - learning_rate: 0.0010
# Epoch 3/10
# 2059/2059 ━━━━━━━━━━━━━━━━━━━━ 78s 29ms/step - accuracy: 0.9630 - loss: 0.1056 - val_accuracy: 0.9694 - val_loss: 0.0872 - learning_rate: 0.0010
# Epoch 4/10
# 2059/2059 ━━━━━━━━━━━━━━━━━━━━ 66s 32ms/step - accuracy: 0.9686 - loss: 0.0882 - val_accuracy: 0.9698 - val_loss: 0.0846 - learning_rate: 0.0010
# Epoch 5/10
# 2059/2059 ━━━━━━━━━━━━━━━━━━━━ 78s 30ms/step - accuracy: 0.9687 - loss: 0.0873 - val_accuracy: 0.9695 - val_loss: 0.0832 - learning_rate: 0.0010
# Epoch 6/10
# 2059/2059 ━━━━━━━━━━━━━━━━━━━━ 87s 32ms/step - accuracy: 0.9712 - loss: 0.0826 - val_accuracy: 0.9716 - val_loss: 0.0802 - learning_rate: 0.0010
# Epoch 7/10
# 2059/2059 ━━━━━━━━━━━━━━━━━━━━ 76s 30ms/step - accuracy: 0.9712 - loss: 0.0812 - val_accuracy: 0.9650 - val_loss: 0.1010 - learning_rate: 0.0010
# Epoch 8/10
# 2059/2059 ━━━━━━━━━━━━━━━━━━━━ 81s 29ms/step - accuracy: 0.9721 - loss: 0.0783 - val_accuracy: 0.9744 - val_loss: 0.0742 - learning_rate: 0.0010
# Epoch 9/10
# 2059/2059 ━━━━━━━━━━━━━━━━━━━━ 82s 29ms/step - accuracy: 0.9737 - loss: 0.0735 - val_accuracy: 0.9718 - val_loss: 0.0753 - learning_rate: 0.0010
# Epoch 10/10
# 2059/2059 ━━━━━━━━━━━━━━━━━━━━ 66s 32ms/step - accuracy: 0.9738 - loss: 0.0729 - val_accuracy: 0.9737 - val_loss: 0.0759 - learning_rate: 0.0010

# %% [markdown]
# # 6- Evaluate and Test the Model

# %%
from sklearn.metrics import classification_report

y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)
# Flatten y_test and y_pred to 1D arrays
y_test_flat = y_test.reshape(-1)  # Shape: (num_samples,)
y_pred_flat = y_pred.reshape(-1)  # Shape: (num_samples,)

# Print classification report
print(classification_report(y_test_flat, y_pred_flat))
# Out:
# 1373/1373 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.98      0.97     22052
#          1.0       0.98      0.97      0.97     21853
#
#     accuracy                           0.97     43905
#    macro avg       0.97      0.97      0.97     43905
# weighted avg       0.97      0.97      0.97     43905

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test_flat, y_pred_flat)
recall = recall_score(y_test_flat, y_pred_flat)
f1 = f1_score(y_test_flat, y_pred_flat)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
# Out:
# Precision: 0.9759
# Recall: 0.9688
# F1-Score: 0.9724

# %%
from keras.saving import save_model

# Save the trained model
save_model(model,"/content/drive/MyDrive/Final project/QRS detection/t_cnn_lstm_model_70sample_MITDB_LUDB_QTDB.keras")
model.save("/content/drive/MyDrive/Final project/QRS detection/t_cnn_lstm_model_70sample_MITDB_LUDB_QTDB.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # 7- Model Test

# %%
from tensorflow.keras.models import load_model
# Load the model later for inference
model = load_model("/content/drive/MyDrive/Final project/QRS detection/t_cnn_lstm_model_70sample_MITDB_LUDB_QTDB.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# !wget -r -N -c -np https://physionet.org/files/edb/1.0.0/

# %%
import wfdb
import numpy as np
record_dir='/content/drive/MyDrive/Final project/dataset/physionet.org/files/edb/1.0.0/'
# Load a new ECG signal (example: another record from MIT-BIH)
# Load a new ECG signal (example: another record from MIT-BIH)
new_record_name='e1301'
new_record_name =  record_dir + new_record_name  # Change this to the desired record
new_record = wfdb.rdrecord(new_record_name)
new_ecg_signal = new_record.p_signal[:, 0]  # Assuming single-channel ECG
G_fs = new_record.fs
print(G_fs)
new_ecg_signal = new_ecg_signal[int(30 * G_fs):int(60 * G_fs)]
# Example usage
time_axis = np.arange(0, len(new_ecg_signal)) / G_fs  # Time axis in seconds

# Optionally smooth the signal
new_normalized_signal = normalize_signal(smooth_signal(bandpass_filter(new_ecg_signal, 1000), window_size=5))
if G_fs != 360:
            new_normalized_signal = resample_signal(new_normalized_signal, original_fs=G_fs, target_fs=360)
            G_fs = 360

print(G_fs)
# Visualize the preprocessed signal
import matplotlib.pyplot as plt
time_axis = [i / G_fs for i in range(len(new_normalized_signal))]
plt.figure(figsize=(12, 4))
#plt.plot(time_axis[:G_fs * 10], new_normalized_signal[:G_fs * 10])
plt.plot(time_axis, new_normalized_signal)
plt.title("Preprocessed New ECG Signal (First 10 seconds)")
plt.xlabel("Time (s)")
plt.ylabel("Normalized Amplitude")
plt.show()
# Out:
# 250
# 360

# %%
# Segment the normalized signal
new_segments,new_start_segments = segment_signal(new_normalized_signal, window_size=G_window_size, overlap=G_overlap)

print(f"Extracted {len(new_segments)} segments with window size {G_window_size} and {G_overlap} samples overlap.")
# Out:
# Extracted 2148 segments with window size 65 and 60 samples overlap.

# %%
# Reshape segments for CNN+LSTM (adding a channel dimension)
new_segments_reshaped = new_segments.reshape(new_segments.shape[0], new_segments.shape[1], 1)

# Print the shape
print("Shape of input segments for model:", new_segments_reshaped.shape)
# Out:
# Shape of input segments for model: (2148, 65, 1)

# %%
# Predict using the trained model
predictions = model.predict(new_segments_reshaped)

# Convert predictions to binary labels (threshold at 0.5)
predicted_labels = (predictions > 0.5).astype(int)

# Print results
print("Predicted QRS presence for each segment:", predicted_labels.flatten())
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Predicted QRS presence for each segment: [1 0 0 ... 1 1 1]

# %% [markdown]
# ## display results

# %%
display_segment(new_normalized_signal,predicted_labels,new_start_segments,0,len(new_normalized_signal)/G_fs)
# Out:
# Number of positive (QRS) segments: 229
# Number of negative (non-QRS) segments: 1919

# %%
display_segment(new_normalized_signal,predicted_labels,new_start_segments,0,5)
# Out:
# Number of positive (QRS) segments: 229
# Number of negative (non-QRS) segments: 1919

# %% [markdown]
# ## Improvement

# %%
def remove_short_qrs_predictions(segment_labels, segmented_signal, segment_starts, min_len=3):
    filtered_labels = []
    filtered_signal = []
    filtered_starts = []

    i = 0
    while i < len(segment_labels):
        if segment_labels[i] == 1:
            # Start of a 1-run
            start = i
            while i + 1 < len(segment_labels) and segment_labels[i + 1] == 1:
                i += 1
            end = i

            run_length = end - start + 1

            if run_length >= min_len:
                # Keep only the middle of a valid QRS run
                mid = (start + end) // 2
                filtered_labels.append(1)
                filtered_signal.append(segmented_signal[mid])
                filtered_starts.append(segment_starts[mid])
            else:
                # Discard this short run
                pass
        else:
            # Keep zeros as-is
            filtered_labels.append(0)
            filtered_signal.append(segmented_signal[i])
            filtered_starts.append(segment_starts[i])
        i += 1

    return filtered_labels, filtered_signal, filtered_starts

# %%
predicted_labels, new_segments, new_start_segments = remove_consecutive_ones( predicted_labels, new_segments, new_start_segments)
predicted_labels, new_segments, new_start_segments = remove_touching_negatives( predicted_labels, new_segments, new_start_segments)
predicted_labels, new_segments, new_start_segments = remove_consecutive_ones( predicted_labels, new_segments, new_start_segments)
predicted_labels=np.array(predicted_labels)

#eval_new_signal(real_labels=real_labels,predicted_labels=predicted_labels)

# %%
print(len(predicted_labels))
#print(len(real_labels))
# Out:
# 1368

# %%
display_segment(new_normalized_signal,predicted_labels,new_start_segments,0,10)
# Out:
# Number of positive (QRS) segments: 21
# Number of negative (non-QRS) segments: 1347
